# %%
# %cd C:\Users\Lenovo\PycharmProjects\pythonProject13\yolo
# Out:
# C:\Users\Lenovo\PycharmProjects\pythonProject13\yolo

# %%
# !python train.py --workers 1 --batch-size 16 --data data/data.yaml --img 244 244 --epochs 5 --cfg cfg/training/yolov7.yaml --weights 'yolov7_training.pt' --name yolov7-cus --hyp data/hyp.scratch.custom.yaml

# %%
# !python detect.py --weights yolov7.pt --conf 0.25 --img-size 640 --source inference/2853723335_44fdafb8fa_o_jpg.rf.14d16f05f40ca506c80778f5c8a4a264  --view_img True
# Out:
# Namespace(weights=['yolov7.pt'], source='inference/images/horses.jpg', img_size=640, conf_thres=0.25, iou_thres=0.45, device='', view_img=False, save_txt=False, save_conf=False, nosave=False, classes=None, agnostic_nms=False, augment=False, update=False, project='runs/detect', name='exp', exist_ok=False, no_trace=False)
# ...
#
# Fusing layers...
#  Convert model to Traced-model...
#  traced_script_module saved!
#  model is traced!
#
# 5 horses, Done. (1105.0ms) Inference, (13.0ms) NMS
#  The image with the result is saved in: runs\detect\exp2\horses.jpg
# Done. (1.189s)
# YOLOR  ff9432c torch 1.12.1+cpu CPU
#
#
#   0%|          | 0.00/72.1M [00:00<?, ?B/s]
#   0%|          | 160k/72.1M [00:00<00:50, 1.50MB/s]
#   0%|          | 352k/72.1M [00:00<00:42, 1.76MB/s]
#   1%|          | 528k/72.1M [00:00<00:42, 1.75MB/s]
#   1%|          | 720k/72.1M [00:00<00:42, 1.75MB/s]
#   1%|1         | 928k/72.1M [00:00<00:39, 1.87MB/s]
#   2%|1         | 1.09M/72.1M [00:00<00:39, 1.87MB/s]
# ...
